# %% [markdown]
# # 1. Project Information

# %% [markdown]
# ## Data Profiling
#
# ### Objective
#
# The objective of this notebook is to perform an initial assessment of the Lending Club dataset before any data cleaning or analytical modeling.
#
# The analysis focuses on:
#
# - Understanding dataset structure
# - Reviewing variable data types
# - Assessing data completeness
# - Identifying potential data quality issues
# - Evaluating target availability
# - Providing recommendations for subsequent data cleaning

# %% [markdown]
# Dataset:
# Lending Club Accepted Loans (2007–2018)
#
# Observation Date:
# December 2019
#
# Role:
# Credit Risk Analyst
#
# Business Context:
# Portfolio monitoring and application risk modeling

# %% [markdown]
# # 2. Load Dataset

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from pathlib import Path

# %%
# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_colwidth", None)

# %%
DATA_PATH = Path("../data/raw/accepted_2007_to_2018Q4.csv")

df = pd.read_csv(
    DATA_PATH,
    low_memory=False
)

# %% [markdown]
# # 3. Dataset Overview

# %%
n_rows = df.shape[0]
n_cols = df.shape[1]

print(f"Rows    : {n_rows:,}")
print(f"Columns : {n_cols}")
# Out:
# Rows    : 2,260,701
# Columns : 151

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), str(38)
# memory usage: 3.1 GB

# %% [markdown]
# The dataset contains over two million historical consumer loan records, providing sufficient observations for portfolio analytics and predictive modeling. The large sample size enables stable estimation across borrower segments and loan vintages.

# %%
text_columns = df.select_dtypes(include=['object', 'string']).columns.tolist()

print(text_columns)
# Out:
# ['id', 'term', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'earliest_cr_line', 'initial_list_status', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d', 'application_type', 'verification_status_joint', 'sec_app_earliest_cr_line', 'hardship_flag', 'hardship_type', 'hardship_reason', 'hardship_status', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_loan_status', 'disbursement_method', 'debt_settlement_flag', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date']

# %%
schema = pd.DataFrame({
    "Variable": df.columns,
    "DataType": df.dtypes.astype(str)
})

schema
# Out:
#                                     Variable DataType
# id                                        id      str
# member_id                          member_id  float64
# loan_amnt                          loan_amnt  float64
# funded_amnt                      funded_amnt  float64
# funded_amnt_inv              funded_amnt_inv  float64
# ...                                      ...      ...
# settlement_status          settlement_status      str
# settlement_date              settlement_date      str
# settlement_amount          settlement_amount  float64
# settlement_percentage  settlement_percentage  float64
# settlement_term              settlement_term  float64
#
# [151 rows x 2 columns]

# %%
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df.tail()
# Out:
#                                                        id  member_id  \
# 2260696                                          88985880        NaN
# 2260697                                          88224441        NaN
# 2260698                                          88215728        NaN
# 2260699  Total amount funded in policy code 1: 1465324575        NaN
# 2260700   Total amount funded in policy code 2: 521953170        NaN
#
#          loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 2260696    40000.0      40000.0          40000.0   60 months     10.49
# 2260697    24000.0      24000.0          24000.0   60 months     14.49
# 2260698    14000.0      14000.0          14000.0   60 months     14.49
# 2260699        NaN          NaN              NaN         NaN       NaN
# 2260700        NaN          NaN              NaN         NaN       NaN
#
#          installment grade sub_grade                    emp_title emp_length  \
# ...

# %%
df.describe(include="all")
# Out:
#               id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count    2260701        0.0  2.260668e+06  2.260668e+06     2.260668e+06
# unique   2260701        NaN           NaN           NaN              NaN
# top     68407277        NaN           NaN           NaN              NaN
# freq           1        NaN           NaN           NaN              NaN
# mean         NaN        NaN  1.504693e+04  1.504166e+04     1.502344e+04
# std          NaN        NaN  9.190245e+03  9.188413e+03     9.192332e+03
# min          NaN        NaN  5.000000e+02  5.000000e+02     0.000000e+00
# 25%          NaN        NaN  8.000000e+03  8.000000e+03     8.000000e+03
# 50%          NaN        NaN  1.290000e+04  1.287500e+04     1.280000e+04
# 75%          NaN        NaN  2.000000e+04  2.000000e+04     2.000000e+04
# max          NaN        NaN  4.000000e+04  4.000000e+04     4.000000e+04
#
#               term      int_rate   installment    grade sub_grade emp_title  \
# ...

# %% [markdown]
# # 4. Variable Categorization

# %%
columns = pd.DataFrame({
    "Variable": df.columns
})

columns
# Out:
#                   Variable
# 0                       id
# 1                member_id
# 2                loan_amnt
# 3              funded_amnt
# 4          funded_amnt_inv
# ..                     ...
# 146      settlement_status
# 147        settlement_date
# 148      settlement_amount
# 149  settlement_percentage
# 150        settlement_term
#
# [151 rows x 1 columns]

# %%
for col in columns.Variable:
    print(col)
# Out:
# id
# member_id
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# url
# desc
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# ...

# %%
columns.to_csv(
    "../data/processed/variable_categories.csv",
    index=True,
    encoding="utf-8-sig"
)

# %% [markdown]
# # 5. Schema Review and Data Type Assessment

# %% [markdown]
# # 6. Missing Value Analysis

# %% [markdown]
# # 7. Duplicate Analysis

# %% [markdown]
# # 8. Cardinality Analysis

# %% [markdown]
# # 9. Numerical Variable Profiling

# %% [markdown]
# # 10. Categorical Variable Profiling

# %% [markdown]
# # 11. Date & Text Variable Review

# %% [markdown]
# # 12. Target Availability Review

# %% [markdown]
# # 13. Initial Data Quality Findings

# %% [markdown]
# # 14. Summary

# %% [markdown]
# # 1. Project Setup

# %% [markdown]
# # 2. Load Dataset

# %%
df = pd.read_csv(
    "../data/raw/accepted_2007_to_2018Q4.csv",
    low_memory=False
)

# %% [markdown]
# # 3. Basic Dataset Information

# %% [markdown]
# # 4. Data Profiling

# %%
profile = pd.DataFrame({
    "column_name": df.columns,
    "data_type": df.dtypes.astype(str).values,
    "missing_count": df.isnull().sum().values,
    "missing_pct": (df.isnull().mean() * 100).round(2).values,
    "unique_values": df.nunique(dropna=True).values,
    "sample_value": [
        df[col].dropna().iloc[0] if df[col].notna().any() else np.nan
        for col in df.columns
    ]
})

profile.head()
# Out:
#        column_name data_type  missing_count  missing_pct  unique_values  \
# 0               id       str              0          0.0        2260701
# 1        member_id   float64        2260701        100.0              0
# 2        loan_amnt   float64             33          0.0           1572
# 3      funded_amnt   float64             33          0.0           1572
# 4  funded_amnt_inv   float64             33          0.0          10057
#
#   sample_value
# 0     68407277
# 1          NaN
# 2       3600.0
# 3       3600.0
# 4       3600.0

# %%
profile.to_csv(
    "../data/processed/data_profile.csv",
    index=False,
    encoding="utf-8-sig"
)

# %% [markdown]
# # 5. Variable Categorization

# %% [markdown]
# ## 5.1. Review Variable List
# - Create folder metadata if it doesn't exist
# - Create the file data_dictionary.xlsx in that folder by using the window explorer
# - Import the the file data_profile.csv into the file data_dictionary.xlsx

# %% [markdown]
# ## 5.2.Define Variable Groups

# %% [markdown]
# ## 5.3. Categorize Variables

# %% [markdown]
# ### Loan Information

# %% [markdown]
# ### Borrower Information

# %% [markdown]
# ### Employment

# %% [markdown]
# ### Credit History

# %% [markdown]
# ### Inquiry

# %% [markdown]
# ### Delinquency

# %% [markdown]
# ### Public Record

# %% [markdown]
# ### Payment

# %% [markdown]
# ### Collection

# %% [markdown]
# ### Recovery

# %% [markdown]
# ### Settlement

# %% [markdown]
# ### Hardship

# %% [markdown]
# ### Joint Applicant

# %% [markdown]
# ### IDs

# %% [markdown]
# ### Miscellaneous

# %% [markdown]
# ## 5.4. Validate Categorization

# %% [markdown]
# # 6. Initial Data Quality Assessment

# %% [markdown]
# # 7. Summary
